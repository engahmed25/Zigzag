# %% [markdown]
# ## ZigZag RES-AI
# #### task 2
# **finish the following notbook**

# %%
# immport libraries
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('cancer_data.csv')

# %%
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99           NaN          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
# show last 10 rows
df.tail(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559  925291         B        11.51         23.93           74.52      403.5
# 560  925292         B        14.05         27.15           91.38      600.4
# 561  925311         B        11.20         29.37           70.67      386.0
# 562  925622         M        15.22         30.62          103.40      716.9
# 563  926125         M        20.92         25.09          143.00     1347.0
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
# what is the datatybes of [diagnosis, symmetry_mean, area_SE , area_max ]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      569 non-null    int64
#  1   diagnosis               569 non-null    object
#  2   radius_mean             569 non-null    float64
#  3   texture_mean            548 non-null    float64
#  4   perimeter_mean          569 non-null    float64
#  5   area_mean               569 non-null    float64
#  6   smoothness_mean         521 non-null    float64
#  7   compactness_mean        569 non-null    float64
#  8   concavity_mean          569 non-null    float64
#  9   concave_points_mean     569 non-null    float64
#  10  symmetry_mean           504 non-null    float64
#  11  fractal_dimension_mean  569 non-null    float64
#  12  radius_SE               569 non-null    float64
#  13  texture_SE              548 non-null    float64
# ...

# %%
df[['diagnosis', 'symmetry_mean', 'area_SE' , 'area_max']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   diagnosis      569 non-null    object
#  1   symmetry_mean  504 non-null    float64
#  2   area_SE        569 non-null    float64
#  3   area_max       569 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 17.9+ KB

# %%
## how many unique value in the dataset

df.nunique()
# Out:
# id                        562
# diagnosis                   2
# radius_mean               451
# texture_mean              459
# perimeter_mean            516
# area_mean                 532
# smoothness_mean           434
# compactness_mean          530
# concavity_mean            530
# concave_points_mean       536
# symmetry_mean             394
# fractal_dimension_mean    494
# radius_SE                 535
# texture_SE                499
# perimeter_SE              526
# area_SE                   523
# smoothness_SE             495
# compactness_SE            534
# concavity_SE              526
# concave_points_SE         500
# symmetry_SE               438
# fractal_dimension_SE      539
# radius_max                452
# texture_max               490
# perimeter_max             510
# area_max                  537
# smoothness_max            378
# compactness_max           523
# concavity_max             532
# concave_points_max        485
# symmetry_max              449
# ...

# %%
## what is the mean value of [radius, area, perimeter, concavity, compactness] of 3 measurment
x= df.describe()
x.loc["mean"]
# Out:
# id                        3.051467e+07
# radius_mean               1.411302e+01
# texture_mean              1.929343e+01
# perimeter_mean            9.187791e+01
# area_mean                 6.532886e+02
# smoothness_mean           9.608712e-02
# compactness_mean          1.045355e-01
# concavity_mean            8.861952e-02
# concave_points_mean       4.883661e-02
# symmetry_mean             1.810911e-01
# fractal_dimension_mean    6.283299e-02
# radius_SE                 4.056807e-01
# texture_SE                1.223139e+00
# perimeter_SE              2.869702e+00
# area_SE                   4.035140e+01
# smoothness_SE             6.978150e-03
# compactness_SE            2.556425e-02
# concavity_SE              3.189833e-02
# concave_points_SE         1.179248e-02
# symmetry_SE               2.076345e-02
# fractal_dimension_SE      3.807774e-03
# radius_max                1.626190e+01
# texture_max               2.566080e+01
# perimeter_max             1.072111e+02
# ...

# %%
#df_mean = df[['radius_mean', 'area_mean', 'perimeter_mean', 'concavity_mean', 'compactness_mean']].groupby(np.arange(len(df))//3).mean()

# %%
## what is the span of [radius, area, perimeter, concavity, compactness] for mean and max 
pd.DataFrame(x.loc['max'] - x.loc['min']) #- x.loc['min']
# Out:
#                                    0
# id                      9.113118e+08
# radius_mean             2.112900e+01
# texture_mean            2.957000e+01
# perimeter_mean          1.447100e+02
# area_mean               2.357500e+03
# smoothness_mean         1.107700e-01
# compactness_mean        3.260200e-01
# concavity_mean          4.268000e-01
# concave_points_mean     2.012000e-01
# symmetry_mean           1.980000e-01
# fractal_dimension_mean  4.748000e-02
# radius_SE               2.761500e+00
# texture_SE              4.524800e+00
# perimeter_SE            2.122300e+01
# area_SE                 5.353980e+02
# smoothness_SE           2.941700e-02
# compactness_SE          1.331480e-01
# concavity_SE            3.960000e-01
# concave_points_SE       5.279000e-02
# symmetry_SE             7.106800e-02
# fractal_dimension_SE    2.894520e-02
# radius_max              2.811000e+01
# texture_max             3.752000e+01
# perimeter_max           2.007900e+02
# ...

# %%
## seprate the 3 measurments [SE, mean, max] in 3 data frames ans show first and last 15 value
# note** the id, diagnosis is common between the 3 dataframes
se= df[['id','diagnosis','radius_SE', 
'texture_SE' 
,'perimeter_SE' 
,'area_SE'  
,'smoothness_SE'  
,'compactness_SE'  
,'concavity_SE'
,'concave_points_SE' 
,'symmetry_SE'  
,'fractal_dimension_SE']]
print(se.head(15) ,'\n', se.tail(15))
# Out:
#           id diagnosis  radius_SE  texture_SE  perimeter_SE  area_SE  \
# 0     842302         M     1.0950         NaN         8.589   153.40
# 1     842517         M     0.5435      0.7339         3.398    74.08
# 2   84300903         M     0.7456      0.7869         4.585    94.03
# 3   84348301         M     0.4956      1.1560         3.445    27.23
# 4   84358402         M     0.7572      0.7813         5.438    94.44
# 5     843786         M     0.3345      0.8902         2.217    27.19
# 6     844359         M     0.4467      0.7732         3.180    53.91
# 7   84458202         M     0.5835      1.3770         3.856    50.96
# 8     844981         M     0.3063      1.0020         2.406    24.32
# 9   84501001         M     0.2976      1.5990         2.039    23.94
# 10    845636         M     0.3795      1.1870         2.466    40.51
# 11  84610002         M     0.5058      0.9849         3.564    54.16
# 12    846226         M     0.9555      3.5680        11.070   116.20
# ...

# %%
mean= df[['id','diagnosis','radius_mean', 
'texture_mean' 
,'perimeter_mean' 
,'area_mean'  
,'smoothness_mean'  
,'compactness_mean'  
,'concavity_mean'
,'concave_points_mean' 
,'symmetry_mean'  
,'fractal_dimension_mean']]
print(mean.head(15) ,'\n', mean.tail(15))
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M        17.99           NaN          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
# 5     843786         M        12.45         15.70           82.57      477.1
# 6     844359         M        18.25         19.98          119.60     1040.0
# 7   84458202         M        13.71         20.83           90.20      577.9
# 8     844981         M        13.00         21.82           87.50      519.8
# 9   84501001         M        12.46         24.04           83.97      475.9
# 10    845636         M        16.02         23.24          102.70      797.8
# ...

# %%
MAX= df[['id','diagnosis','radius_max', 
'texture_max'
,'perimeter_max' 
,'area_max'  
,'smoothness_max'  
,'compactness_max'  
,'concavity_max'
,'concave_points_max' 
,'symmetry_max' 
,'fractal_dimension_max']]
print(MAX.head(15) ,'\n', MAX.tail(15))
# Out:
#           id diagnosis  radius_max  texture_max  perimeter_max  area_max  \
# 0     842302         M       25.38          NaN         184.60    2019.0
# 1     842517         M       24.99        23.41         158.80    1956.0
# 2   84300903         M       23.57        25.53         152.50    1709.0
# 3   84348301         M       14.91        26.50          98.87     567.7
# 4   84358402         M       22.54        16.67         152.20    1575.0
# 5     843786         M       15.47        23.75         103.40     741.6
# 6     844359         M       22.88        27.66         153.20    1606.0
# 7   84458202         M       17.06        28.14         110.60     897.0
# 8     844981         M       15.49        30.73         106.20     739.3
# 9   84501001         M       15.09        40.68          97.65     711.4
# 10    845636         M       19.19        33.88         123.80    1150.0
# 11  84610002         M       20.42        27.28         136.50    1299.0
# ...
