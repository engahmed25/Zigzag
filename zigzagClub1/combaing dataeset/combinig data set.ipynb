# %% [markdown]
# # combinig data set

# %%
import pandas as pd 
import numpy as np

# %%
shops = pd.read_csv('C:\\Users\\Mcs\\Desktop\\RES jyputer\\combaing dataeset\\shops.csv')
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
sales= pd.read_csv('C:\\Users\\Mcs\\Desktop\\RES jyputer\\combaing dataeset\\sales_train.csv')
sales.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
items= pd.read_csv('C:\\Users\\Mcs\\Desktop\\RES jyputer\\combaing dataeset\\items.csv\\items.csv')
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
items_categ=pd.read_csv ('C:\\Users\\Mcs\\Desktop\\RES jyputer\\combaing dataeset\\item_categories.csv')
items_categ.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
shops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
items_categ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
sales.dropna()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
x = pd.merge(items,items_categ, how='inner' ,on='item_category_id')
x
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 2        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 3            ***КОРОБКА (СТЕКЛО)                       D        4
# 4      ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
# ...                                                  ...      ...
# 22165  Элемент питания GP 15AU (LR6) - Блистер 2 шт U...    22095
# 22166       Элемент питания GP 24A (LR03) - Блистер 2 шт    22096
# 22167  Элемент питания GP 24AU (LR03) - Блистер 2 шт ...    22097
# 22168                   Элемент питания КОСМОС LR03 2*BL    22098
# 22169  Элемент питания СТАРТ ZT 15A (LR6) - Блистер 2 шт    22099
#
#        item_category_id item_category_name
# 0                    40         Кино - DVD
# 1                    40         Кино - DVD
# ...

# %%
y = pd.merge(x,sales, how='inner' ,on='item_id')
y
# Out:
#                                                  item_name  item_id  \
# 0                ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1            ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 2            ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3          ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4          ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# ...                                                    ...      ...
# 2935844  Элемент питания GP 24AU (LR03) - Блистер 2 шт ...    22097
# 2935845                   Элемент питания КОСМОС LR03 2*BL    22098
# 2935846  Элемент питания СТАРТ ZT 15A (LR6) - Блистер 2 шт    22099
# 2935847  Элемент питания СТАРТ ZT 15A (LR6) - Блистер 2 шт    22099
# 2935848  Элемент питания СТАРТ ZT 15A (LR6) - Блистер 2 шт    22099
#
#          item_category_id item_category_name        date  date_block_num  \
# 0                      40         Кино - DVD  01.09.2014              20
# ...

# %%
z = pd.merge(y,shops, how='inner' ,on='shop_id')
z
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# ...                                                  ...      ...
# 2935844                         Манга Врата Штейна Том 1    14957
# 2935845                         Манга Врата Штейна Том 1    14957
# 2935846                         Манга Врата Штейна Том 1    14957
# 2935847                Элемент питания DURACELL LR06-BC2    22088
# 2935848                Элемент питания DURACELL LR06-BC2    22088
#
#          item_category_id      item_category_name        date  date_block_num  \
# 0                      40              Кино - DVD  01.09.2014              20
# ...

# %%
z.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Aggregations and Groupby
